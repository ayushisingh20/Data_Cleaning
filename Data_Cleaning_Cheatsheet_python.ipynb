# %% [markdown]
# ## Create a Sample Data Set

# %%
import pandas as pd
import numpy as np

data = {
    "Name": ["Alice ", "Bob", "Charlie", "Alice ", "Eve", None],
    "Age": [25, 30, np.nan, 25, 22, 29],
    "City": ["New-York", "Paris", None, "New-York", "Paris", "Paris"],
    "Date": ["2023-01-01", "2023-02-15", "2023-03-10", "2023-01-01", "2023-04-12", None]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name   Age      City        Date
# 0   Alice   25.0  New-York  2023-01-01
# 1      Bob  30.0     Paris  2023-02-15
# 2  Charlie   NaN      None  2023-03-10
# 3   Alice   25.0  New-York  2023-01-01
# 4      Eve  22.0     Paris  2023-04-12
# 5     None  29.0     Paris        None

# %% [markdown]
# ## Dataset Overview

# %%
df.shape
# Out:
# (6, 4)

# %%
df.head()
# Out:
#       Name   Age      City        Date
# 0   Alice   25.0  New-York  2023-01-01
# 1      Bob  30.0     Paris  2023-02-15
# 2  Charlie   NaN      None  2023-03-10
# 3   Alice   25.0  New-York  2023-01-01
# 4      Eve  22.0     Paris  2023-04-12

# %%
df.tail()
# Out:
#       Name   Age      City        Date
# 1      Bob  30.0     Paris  2023-02-15
# 2  Charlie   NaN      None  2023-03-10
# 3   Alice   25.0  New-York  2023-01-01
# 4      Eve  22.0     Paris  2023-04-12
# 5     None  29.0     Paris        None

# %%
df.sample(3,random_state=42)
# Out:
#      Name   Age      City        Date
# 0  Alice   25.0  New-York  2023-01-01
# 1     Bob  30.0     Paris  2023-02-15
# 5    None  29.0     Paris        None

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     5 non-null      float64
#  2   City    5 non-null      object
#  3   Date    5 non-null      object
# dtypes: float64(1), object(3)
# memory usage: 324.0+ bytes

# %%
df.describe()
# Out:
#              Age
# count   5.000000
# mean   26.200000
# std     3.271085
# min    22.000000
# 25%    25.000000
# 50%    25.000000
# 75%    29.000000
# max    30.000000

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City', 'Date'], dtype='object')

# %%
df.nunique()
# Out:
# Name    4
# Age     4
# City    2
# Date    4
# dtype: int64

# %% [markdown]
# ## Missing Values

# %%
df.isnull().sum()
# Out:
# Name    1
# Age     1
# City    1
# Date    1
# dtype: int64

# %%
df.dropna() #removes rows with NaN
# Out:
#      Name   Age      City        Date
# 0  Alice   25.0  New-York  2023-01-01
# 1     Bob  30.0     Paris  2023-02-15
# 3  Alice   25.0  New-York  2023-01-01
# 4     Eve  22.0     Paris  2023-04-12

# %%
df.fillna(0) #Replaces NaN with 0
# Out:
#       Name   Age      City        Date
# 0   Alice   25.0  New-York  2023-01-01
# 1      Bob  30.0     Paris  2023-02-15
# 2  Charlie   0.0         0  2023-03-10
# 3   Alice   25.0  New-York  2023-01-01
# 4      Eve  22.0     Paris  2023-04-12
# 5        0  29.0     Paris           0

# %%
df['Age'].fillna(df['Age'].mean())
# Out:
# 0    25.0
# 1    30.0
# 2    26.2
# 3    25.0
# 4    22.0
# 5    29.0
# Name: Age, dtype: float64

# %%
df['City'].fillna(df['City'].mode()[0])
# Out:
# 0    New-York
# 1       Paris
# 2       Paris
# 3    New-York
# 4       Paris
# 5       Paris
# Name: City, dtype: object

# %%
df['Age'].interpolate() # Fills numeric NaNs by linear interpolation


#Use fillna(mean/median/mode) for general datasets.
#Use interpolate() when data has a natural progression (time, numeric series).By default, it uses linear interpolation (straight line between points).
# Example of interpolate() : If you have temperature readings for 1 PM (25°C) and 3 PM (27°C), but missing 2 PM → interpolation will fill ~26°C.
# Out:
# 0    25.0
# 1    30.0
# 2    27.5
# 3    25.0
# 4    22.0
# 5    29.0
# Name: Age, dtype: float64

# %% [markdown]
# ## Dublicates

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df
# Out:
#       Name   Age      City        Date
# 0   Alice   25.0  New-York  2023-01-01
# 1      Bob  30.0     Paris  2023-02-15
# 2  Charlie   NaN      None  2023-03-10
# 3   Alice   25.0  New-York  2023-01-01
# 4      Eve  22.0     Paris  2023-04-12
# 5     None  29.0     Paris        None

# %%
df.drop_duplicates()
# Out:
#       Name   Age      City        Date
# 0   Alice   25.0  New-York  2023-01-01
# 1      Bob  30.0     Paris  2023-02-15
# 2  Charlie   NaN      None  2023-03-10
# 4      Eve  22.0     Paris  2023-04-12
# 5     None  29.0     Paris        None

# %% [markdown]
# ## Data type and Conversion

# %%
df.dtypes
# Out:
# Name     object
# Age     float64
# City     object
# Date     object
# dtype: object

# %%
pd.to_numeric(df['Age'],errors='coerce').astype('Int64')
# Out:
# 0      25
# 1      30
# 2    <NA>
# 3      25
# 4      22
# 5      29
# Name: Age, dtype: Int64

# %%
pd.to_datetime(df['Date'],errors='coerce')
# Out:
# 0   2023-01-01
# 1   2023-02-15
# 2   2023-03-10
# 3   2023-01-01
# 4   2023-04-12
# 5          NaT
# Name: Date, dtype: datetime64[ns]

# %%
df['City'].astype('category')

#Categorical data type is used for repeated labels (like City names, Gender, Yes/No, etc.).
#Internally, Pandas stores categories as integer codes (0, 1, 2, …) instead of keeping the full string for each row.
#It also stores a mapping (e.g., 0 → Delhi, 1 → Mumbai, 2 → Pune).
# Out:
# 0    New-York
# 1       Paris
# 2         NaN
# 3    New-York
# 4       Paris
# 5       Paris
# Name: City, dtype: category
# Categories (2, object): ['New-York', 'Paris']

# %% [markdown]
# ## String Cleaning

# %%
df['Name'].str.strip() # Removes spaces from "Alice "
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      Alice
# 4        Eve
# 5       None
# Name: Name, dtype: object

# %%
df['Name'].str.lower()
# Out:
# 0     alice
# 1        bob
# 2    charlie
# 3     alice
# 4        eve
# 5       None
# Name: Name, dtype: object

# %%
df['City'].str.replace('[^a-zA-Z0-9]','',regex=True) # Removes special characters (New-York → NewYork)
# Out:
# 0    NewYork
# 1      Paris
# 2       None
# 3    NewYork
# 4      Paris
# 5      Paris
# Name: City, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     5 non-null      float64
#  2   City    5 non-null      object
#  3   Date    5 non-null      object
# dtypes: float64(1), object(3)
# memory usage: 324.0+ bytes

# %%
df.head()
# Out:
#       Name   Age      City        Date
# 0   Alice   25.0  New-York  2023-01-01
# 1      Bob  30.0     Paris  2023-02-15
# 2  Charlie   NaN      None  2023-03-10
# 3   Alice   25.0  New-York  2023-01-01
# 4      Eve  22.0     Paris  2023-04-12

# %%
df['City'] = df['City'].fillna('')  # replace None/NaN with empty string
df['City'] = df['City'].str.replace('[^a-zA-Z0-9]', ' ', regex=True)
df['City'] = df['City'].str.split()

# %%
print(df)
# Out:
#       Name   Age         City        Date
# 0   Alice   25.0  [New, York]  2023-01-01
# 1      Bob  30.0      [Paris]  2023-02-15
# 2  Charlie   NaN           []  2023-03-10
# 3   Alice   25.0  [New, York]  2023-01-01
# 4      Eve  22.0      [Paris]  2023-04-12
# 5     None  29.0      [Paris]        None

# %% [markdown]
# ## Outliers & Numeric Cleaning

# %%
# detect outliers using quantiles
print(df['Age'].quantile([0.01,0.99])) #Calculates the 1st percentile and 99th percentile.

# 1% quantile (0.01) → The value below which 1% of the ages lie.
# 99% quantile (0.99) → The value below which 99% of the ages lie.
# Anything below the 1% or above the 99% can be considered an outlier.
# Out:
# 0.01    22.12
# 0.99    29.96
# Name: Age, dtype: float64

# %%
# trim top 5% extreme values
upper_limit =df['Age'].quantile(0.95)
df['Age_clipped'] =df['Age'].clip(lower=0,upper= upper_limit)
# Any value above upper_limit will be replaced with upper_limit. So it “trims” extreme values to reduce their effect.
print(f"\nAge column after clipping top 5% (upper limit={upper_limit}):")
print(df[['Age', 'Age_clipped']])
# Out:
# Age column after clipping top 5% (upper limit=29.8):
#     Age  Age_clipped
# 0  25.0         25.0
# 1  30.0         29.8
# 2   NaN          NaN
# 3  25.0         25.0
# 4  22.0         22.0
# 5  29.0         29.0

# %%
filtered_df = df[df['Age']< upper_limit]
filtered_df
# Out:
#      Name   Age         City        Date  Age_clipped
# 0  Alice   25.0  [New, York]  2023-01-01         25.0
# 3  Alice   25.0  [New, York]  2023-01-01         25.0
# 4     Eve  22.0      [Paris]  2023-04-12         22.0
# 5    None  29.0      [Paris]        None         29.0

# %% [markdown]
# ###  Other methods
# 1. IQR Method – Remove values outside Q1 - 1.5 * IQR to Q3 + 1.5 * IQR.
# 2. Z-score Method – Remove values where |Z| > 3 (far from mean).

# %% [markdown]
# ## Column and index Managemnet

# %%
df.rename(columns={'Name':'FullName'})
# Out:
#   FullName   Age         City        Date  Age_clipped
# 0   Alice   25.0  [New, York]  2023-01-01         25.0
# 1      Bob  30.0      [Paris]  2023-02-15         29.8
# 2  Charlie   NaN           []  2023-03-10          NaN
# 3   Alice   25.0  [New, York]  2023-01-01         25.0
# 4      Eve  22.0      [Paris]  2023-04-12         22.0
# 5     None  29.0      [Paris]        None         29.0

# %%
df.drop(['City'],axis=1)
# Out:
#       Name   Age        Date  Age_clipped
# 0   Alice   25.0  2023-01-01         25.0
# 1      Bob  30.0  2023-02-15         29.8
# 2  Charlie   NaN  2023-03-10          NaN
# 3   Alice   25.0  2023-01-01         25.0
# 4      Eve  22.0  2023-04-12         22.0
# 5     None  29.0        None         29.0

# %%
df = df.drop([0, 2])
df.reset_index(drop=True)
# Out:
#      Name   Age         City        Date  Age_clipped
# 0     Bob  30.0      [Paris]  2023-02-15         29.8
# 1  Alice   25.0  [New, York]  2023-01-01         25.0
# 2     Eve  22.0      [Paris]  2023-04-12         22.0
# 3    None  29.0      [Paris]        None         29.0

# %%
df['AgePlus5']= df['Age'].fillna(0)+5
df.head()
# Out:
#      Name   Age         City        Date  Age_clipped  AgePlus5
# 1     Bob  30.0      [Paris]  2023-02-15         29.8      35.0
# 3  Alice   25.0  [New, York]  2023-01-01         25.0      30.0
# 4     Eve  22.0      [Paris]  2023-04-12         22.0      27.0
# 5    None  29.0      [Paris]        None         29.0      34.0

# %% [markdown]
# ## Final Checks

# %%
df.info() # verify structure
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 1 to 5
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         3 non-null      object
#  1   Age          4 non-null      float64
#  2   City         4 non-null      object
#  3   Date         3 non-null      object
#  4   Age_clipped  4 non-null      float64
#  5   AgePlus5     4 non-null      float64
# dtypes: float64(3), object(3)
# memory usage: 396.0+ bytes

# %%
df.isnull().sum()
# Out:
# Name           1
# Age            0
# City           0
# Date           1
# Age_clipped    0
# AgePlus5       0
# dtype: int64

# %%
df.describe(include='all') # Full overview of categorical + numeric columns
# Out:
#        Name        Age     City        Date  Age_clipped   AgePlus5
# count     3   4.000000        4           3     4.000000   4.000000
# unique    3        NaN        2           3          NaN        NaN
# top     Bob        NaN  [Paris]  2023-02-15          NaN        NaN
# freq      1        NaN        3           1          NaN        NaN
# mean    NaN  26.500000      NaN         NaN    26.450000  31.500000
# std     NaN   3.696846      NaN         NaN     3.634556   3.696846
# min     NaN  22.000000      NaN         NaN    22.000000  27.000000
# 25%     NaN  24.250000      NaN         NaN    24.250000  29.250000
# 50%     NaN  27.000000      NaN         NaN    27.000000  32.000000
# 75%     NaN  29.250000      NaN         NaN    29.200000  34.250000
# max     NaN  30.000000      NaN         NaN    29.800000  35.000000

# %% [markdown]
# Thank you !
